# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("1. Domestic violence in the states.")
print("2. Crime against women(IPC+SLL) in 2014, 2016 and 2018. ")
print("3. Percentage share of state/UT(2016).")
print("4. Rank based on Incidence/Percentage_sharee(2016).")
print("5. Rate of Cognizable Crimes in India(2016).")
print("6. Rank based on Crime rates (2016).")
print("7. Rate of total Crime against women(2018).")
print()
while True:
    print()
    choice=int(input('Enter your choice:'))
    
    if choice==1:
        data1= {'State':['Karnataka', 'Arunachal Pradesh', 'Assam', 'Bihar', 'CHattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir'],
                'Crime against women 2014':[16526, 351, 19169, 15393, 6301, 508, 10854, 7010, 1529, 3327],
                'Crime against women 2016':[16362, 367, 20869, 13400, 5947, 317, 3532, 9839, 1222, 2850],
                'Crime against women 2018':[16438, 368, 27728, 16920, 8587, 362, 8520, 2917, 1633, 3437], 
                'Percentage_share of State/UT(2016)':[4.8, 1.0, 6.2, 4.0, 1.8, 0.1, 2.5, 2.9, 0.4, 0.8],
                'Rank based on incidence/Percentage_share(2016)': [9, 15, 11, 22, 27, 29, 17, 14, 10, 18],
                'Rate of cognizable Crimes(2016)':[81.3, 55.2, 70.0, 59.6, 24.7, 69.3, 22.5, 27.7, 11.2, 71.1],
                'Rank based on Crimes rate(2016)':[27, 16, 20, 15, 22, 20, 17, 18,11, 24],
                'Rate of total Crime against Women(2018)':[163.2, 51.1, 66.2, 49.9, 30.5, 29.7,63.6, 33.3, 47.7, 71.4]}
        Violence=pd.DataFrame(data1)
        print(Violence)
        print() 
    if choice==2:
        data2= {'State':['Karnataka', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir'],
                'Crime against women 2014':[16526, 351, 19169, 15393, 6301, 508, 10854, 7010, 1529, 3327],
                'Crime against women 2016':[16362, 367, 20869, 13400, 5947, 317, 3532, 9839, 1222, 2850],
                'Crime against women 2018':[16438, 368, 27728, 16920, 8587, 362, 8520, 2917, 1633, 3437]}
        Crime=pd.DataFrame(data2)
        print(Crime)
    if choice==3:
        data3= {'State':['Karnataka', 'Arunachal Pradesh', 'Assam', 'Bihar', 'CHattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir'],
                'Percentage_share of State/UT(2016)':[4.8, 1.0, 6.2, 4.0, 1.8, 0.1, 2.5, 2.9, 0.4, 0.8]}
        Percentage_share=pd.DataFrame(data3)
        print(Percentage_share)
        print()
    if choice==4:
        data4= {'State':['Karnataka', 'Arunachal Pradesh', 'Assam', 'Bihar', 'CHattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir'],
                'Rank based on incidence/Percentage_share(2016)': [9, 15, 11, 22, 27, 29, 17, 14, 10, 18]}
        Rank=pd.DataFrame(data4)
        print(Rank)
        print()
    if choice==5:
        data5= {'State':['Karnataka', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir'],
                'Rate of cognizable Crimes(2016)':[81.3, 55.2, 70.0, 59.6, 24.7, 69.3, 22.5, 27.7, 11.2, 71.1]}
        Rate=pd.DataFrame(data5)
        print(Rate)
        print()
    if choice==6:
        data6=  {'State':['Karnataka', 'Arunachal Pradesh', 'Assam', 'Bihar', 'CHattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir'],
                'Rank based on Crimes rate(2016)':[27, 16, 20, 15, 22, 20, 17, 18,11, 24]}
        Rank_2=pd.DataFrame(data6)
        print(Rank_2)
        print()
    if choice==7:
        data7=  {'State':['Karnataka', 'Arunachal Pradesh', 'Assam', 'Bihar', 'CHattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir'],
                'Rate of total Crime against Women(2018)':[163.2, 51.1, 66.2, 49.9, 30.5, 29.7,63.6, 33.3, 47.7, 71.4]}
        Rate_2=pd.DataFrame(data7)
        print(Rate_2)
        print()
# Out:
# 1. Domestic violence in the states.
# 2. Crime against women(IPC+SLL) in 2014, 2016 and 2018.
# 3. Percentage share of state/UT(2016).
# 4. Rank based on Incidence/Percentage_sharee(2016).
# 5. Rate of Cognizable Crimes in India(2016).
# 6. Rank based on Crime rates (2016).
# 7. Rate of total Crime against women(2018).
#
#
# Enter your choice:1
#                State  Crime against women 2014  Crime against women 2016  \
# 0          Karnataka                     16526                     16362
# 1  Arunachal Pradesh                       351                       367
# 2              Assam                     19169                     20869
# 3              Bihar                     15393                     13400
# 4        CHattisgarh                      6301                      5947
# 5                Goa                       508                       317
# 6            Gujarat                     10854                      3532
# ...
